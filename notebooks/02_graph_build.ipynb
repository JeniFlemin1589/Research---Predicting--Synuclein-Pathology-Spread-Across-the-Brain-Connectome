# %% [markdown]
# # 02 Graph Build
#
# Build and inspect the static region graph used by the GNN branch.

# %%
from pathlib import Path
import pandas as pd
from ripgnn.data.graph import build_region_graph

data_dir = Path('../data/demo')
region_meta = pd.read_csv(data_dir / 'region_meta.csv')
edges = pd.read_csv(data_dir / 'edges.csv')
graph = build_region_graph(
    region_meta,
    edges,
    ['hnoca_cortex_prior', 'hnoca_striatum_prior', 'hnoca_midbrain_prior', 'hnoca_hindbrain_prior'],
)
graph
# Out:
# RegionGraph(region_ids=['cortex', 'striatum', 'midbrain', 'hindbrain', 'thalamus', 'glia_niche'], edge_index=tensor([[2, 1, 2, 3, 4, 5, 5, 1, 0, 3, 4, 0, 2, 1],
#         [1, 0, 3, 4, 0, 2, 1, 2, 1, 2, 3, 4, 5, 5]]), edge_weight=tensor([0.8754, 0.7282, 0.8068, 0.5582, 0.6993, 0.7219, 0.6344, 0.8754, 0.7282,
#         0.8068, 0.5582, 0.6993, 0.7219, 0.6344]), static_features=tensor([[0.9500, 0.1500, 0.2500, 0.1000],
#         [0.2500, 0.9500, 0.4500, 0.2500],
#         [0.1500, 0.5000, 0.9500, 0.7500],
#         [0.1000, 0.2500, 0.8000, 0.9500],
#         [0.7000, 0.6500, 0.4000, 0.2000],
#         [0.3000, 0.3000, 0.5000, 0.5500]]))
