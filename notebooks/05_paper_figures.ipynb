# %% [markdown]
# # 05 Paper Figures
#
# Assemble the saved artifacts into figures for the manuscript.

# %%
from pathlib import Path
from IPython.display import Image, display

run_dir = Path('../outputs/demo_dual_branch')
for name in ['val_rip_heatmap.png', 'test_rip_heatmap.png', 'attention_hubs.png', 'occlusion_hubs.png']:
    path = run_dir / name
    if path.exists():
        display(Image(filename=str(path)))
